# %%
#install requirements
#%pip install -r requirements.txt

# %%
import os
import pandas as pd
from src.loading_functions import load_or_download_lego_data, preprocess_data
import requests

# %%
#get cwd
cwd = os.getcwd()
#get data folder
data_folder = os.path.join(cwd, 'data')

# %% [markdown]
# ## Data Preprocessing
# clean the data, such that it's easier to work with.

# %%
#load or download lego data
df = load_or_download_lego_data(data_folder) #check if you have dependencies installed. else run first cell
df = preprocess_data(df, include_monthly = False)
# Out:
# Loading data from c:\Users\MGAJ\OneDrive - Danmarks Tekniske Universitet\DTU\Kandidat\4_Semester\Social Data Visualization\MarcusGalea.github.io\data\lego_sets.csv
# c:\Users\MGAJ\OneDrive - Danmarks Tekniske Universitet\DTU\Kandidat\4_Semester\Social Data Visualization\MarcusGalea.github.io\src\loading_functions.py:10: DtypeWarning: Columns (34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(os.path.join(data_folder, 'lego_sets.csv'))
# c:\Users\MGAJ\OneDrive - Danmarks Tekniske Universitet\DTU\Kandidat\4_Semester\Social Data Visualization\MarcusGalea.github.io\src\loading_functions.py:47: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[df.columns[date_columns]] = df[df.columns[date_columns]].applymap(lambda x: x.split("T")[0])

# %%
df
# Out:
#       setID  number  numberVariant                                     name  \
# 0      4785    7280              1              Straight & Crossroad Plates
# 1      4786    7281              1          T-Junction & Curved Road Plates
# 2      5364    7895              1                         Switching Tracks
# 3      6375    8881              1                              Battery Box
# 4      6394    8882              1                                 XL-Motor
# ...     ...     ...            ...                                      ...
# 1989  33711   41958              1              Extra DOTS Series 7 - Sport
# 1990  33844   71034             13  LEGO Minifigures - Series 23 - Complete
# 1991  33920   40572              1                      Penguin & Snowflake
# 1992  33945   71034             12                     Green Dragon Costume
# 1993  34231   71037             12                            Newspaper Kid
#
#       year                    theme      themeGroup     subtheme    category  \
# 0     2005                     City      Modern day  Road Plates      Normal
# 1     2005                     City      Modern day  Road Plates      Normal
# 2     2006                     City      Modern day       Trains      Normal
# 3     2008          Power Functions       Technical  Accessories      Normal
# 4     2008          Power Functions       Technical  Accessories      Normal
# ...    ...                      ...             ...          ...         ...
# 1989  2022                     Dots  Art and crafts   Extra Dots      Normal
# 1990  2022  Collectable Minifigures   Miscellaneous    Series 23  Collection
# 1991  2022                 Seasonal   Miscellaneous    Christmas      Normal
# 1992  2022  Collectable Minifigures   Miscellaneous    Series 23      Normal
# 1993  2023  Collectable Minifigures   Miscellaneous    Series 24      Normal
#
#       released  ...  UK_dateLastAvailable  CA_retailPrice  \
# 0            1  ...            2018-12-27         13.5932
# 1            1  ...            2018-12-07         13.5932
# 2            1  ...            2018-10-27         13.5932
# 3            1  ...            2020-10-02          5.7732
# 4            1  ...            2020-10-15          7.8132
# ...        ...  ...                   ...             ...
# 1989         1  ...            2023-05-19          3.3932
# 1990         1  ...            2022-08-12          3.3932
# 1991         1  ...            2022-11-24          8.8332
# 1992         1  ...            2022-09-11          3.3932
# 1993         1  ...            2023-03-20          4.0732
#
#       CA_dateFirstAvailable  CA_dateLastAvailable  DE_retailPrice  \
# 0                2010-09-24            2018-11-20            9.99
# 1                2010-09-24            2018-11-23            9.99
# 2                2010-09-24            2018-06-16           19.99
# 3                2010-09-24            2020-11-16            7.79
# 4                2010-09-24            2020-11-22           11.69
# ...                     ...                   ...             ...
# 1989             2022-05-31            2023-02-25            3.99
# 1990             2022-07-26            2022-08-12            3.99
# 1991             2022-10-18            2022-11-03            9.99
# 1992             2022-08-13            2022-09-11            3.99
# 1993             2022-11-24            2023-05-05            3.99
#
#       DE_dateFirstAvailable DE_dateLastAvailable PL_retailPrice       Date  \
# 0                2015-01-14           2019-01-01         9.1977 2018-06-01
# 1                2015-01-14           2018-11-27         9.1977 2018-07-01
# 2                2015-01-31           2018-10-28        19.5477 2018-06-01
# 3                2015-04-02           2020-10-03         8.5077 2018-08-01
# 4                2015-01-14           2020-10-16        12.6477 2018-06-01
# ...                     ...                  ...            ...        ...
# 1989             2022-08-04           2023-05-20         4.1377 2022-05-01
# 1990             2022-08-04           2022-08-12         3.9077 2022-08-01
# 1991             2022-08-04           2022-11-25        10.3477 2022-08-01
# 1992             2022-08-13           2022-09-11         3.9077 2022-08-01
# 1993             2022-11-25           2023-03-21         4.1377 2022-12-01
#
#                         status
# 0              Retired Product
# 1              Retired Product
# 2              Retired Product
# 3              Retired Product
# 4              Retired Product
# ...                        ...
# 1989              Lack of data
# 1990      A gift upon purchase
# 1991              Lack of data
# 1992      A gift upon purchase
# 1993  Temporarily out of stock
#
# [1994 rows x 39 columns]
