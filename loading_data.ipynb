# %%
#install requirements
#%pip install -r requirements.txt

# %%
import os
import pandas as pd
from src.loading_functions import load_or_download_lego_data, preprocess_data
import requests

# %%
#get cwd
cwd = os.getcwd()
#get data folder
data_folder = os.path.join(cwd, 'data')

# %% [markdown]
# ## Data Preprocessing
# clean the data, such that it's easier to work with.

# %%
#load or download lego data
df = load_or_download_lego_data(data_folder) #check if you have dependencies installed. else run first cell
df = preprocess_data(df, include_monthly = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #load or download lego data
# ----> 2 df = load_or_download_lego_data(data_folder) #check if you have dependencies installed. else run first cell
#       3 df = preprocess_data(df, include_monthly = False)
#
# NameError: name 'load_or_download_lego_data' is not defined

# %%
df
# Out:
#         setID  number  numberVariant                             name  year  \
# 4136    34231   71037             12                    Newspaper Kid  2023
# 4137    34231   71037             12                    Newspaper Kid  2023
# 4138    34231   71037             12                    Newspaper Kid  2023
# 4139    34231   71037             12                    Newspaper Kid  2023
# 4140    34231   71037             12                    Newspaper Kid  2023
# ...       ...     ...            ...                              ...   ...
# 609804   4786    7281              1  T-Junction & Curved Road Plates  2005
# 609805   4786    7281              1  T-Junction & Curved Road Plates  2005
# 609806   4786    7281              1  T-Junction & Curved Road Plates  2005
# 609807   4786    7281              1  T-Junction & Curved Road Plates  2005
# 609808   4786    7281              1  T-Junction & Curved Road Plates  2005
#
#                           theme     themeGroup     subtheme category  \
# 4136    Collectable Minifigures  Miscellaneous    Series 24   Normal
# 4137    Collectable Minifigures  Miscellaneous    Series 24   Normal
# 4138    Collectable Minifigures  Miscellaneous    Series 24   Normal
# 4139    Collectable Minifigures  Miscellaneous    Series 24   Normal
# 4140    Collectable Minifigures  Miscellaneous    Series 24   Normal
# ...                         ...            ...          ...      ...
# 609804                     City     Modern day  Road Plates   Normal
# 609805                     City     Modern day  Road Plates   Normal
# 609806                     City     Modern day  Road Plates   Normal
# 609807                     City     Modern day  Road Plates   Normal
# 609808                     City     Modern day  Road Plates   Normal
#
#         released  ...  CA_retailPrice  CA_dateFirstAvailable  \
# 4136           1  ...            5.99             2022-11-24
# 4137           1  ...            5.99             2022-11-24
# 4138           1  ...            5.99             2022-11-24
# 4139           1  ...            5.99             2022-11-24
# 4140           1  ...            5.99             2022-11-24
# ...          ...  ...             ...                    ...
# 609804         1  ...           19.99             2010-09-24
# 609805         1  ...           19.99             2010-09-24
# 609806         1  ...           19.99             2010-09-24
# 609807         1  ...           19.99             2010-09-24
# 609808         1  ...           19.99             2010-09-24
#
#         CA_dateLastAvailable  DE_retailPrice  DE_dateFirstAvailable  \
# 4136              2023-05-05            3.99             2022-11-25
# 4137              2023-05-05            3.99             2022-11-25
# 4138              2023-05-05            3.99             2022-11-25
# 4139              2023-05-05            3.99             2022-11-25
# 4140              2023-05-05            3.99             2022-11-25
# ...                      ...             ...                    ...
# 609804            2018-11-23            9.99             2015-01-14
# 609805            2018-11-23            9.99             2015-01-14
# 609806            2018-11-23            9.99             2015-01-14
# 609807            2018-11-23            9.99             2015-01-14
# 609808            2018-11-23            9.99             2015-01-14
#
#         DE_dateLastAvailable PL_retailPrice     Date  PriceMonthPLN  \
# 4136              2023-03-21          17.99  2022-12          22.60
# 4137              2023-03-21          17.99  2023-01          17.98
# 4138              2023-03-21          17.99  2023-02          16.00
# 4139              2023-03-21          17.99  2023-03          12.51
# 4140              2023-03-21          17.99  2023-04          17.99
# ...                      ...            ...      ...            ...
# 609804            2018-11-27          39.99  2022-04           0.00
# 609805            2018-11-27          39.99  2022-05           0.00
# 609806            2018-11-27          39.99  2022-06           0.00
# 609807            2018-11-27          39.99  2022-07           0.00
# 609808            2018-11-27          39.99  2022-08           0.00
#
#                           status
# 4136    Temporarily out of stock
# 4137    Temporarily out of stock
# 4138    Temporarily out of stock
# 4139    Temporarily out of stock
# 4140    Temporarily out of stock
# ...                          ...
# 609804           Retired Product
# 609805           Retired Product
# 609806           Retired Product
# 609807           Retired Product
# 609808           Retired Product
#
# [81786 rows x 40 columns]
